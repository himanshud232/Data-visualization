# %%
from vega_datasets import data
import pandas as pd
import altair as alt
source=pd.read_csv('C://Users/Yoga 910/Desktop/Life Expectancy_Group7.csv')

alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
source.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#      ...      Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0    ...        6.0               8.16         65.0        0.1  584.259210
# 1    ...       58.0               8.18         62.0        0.1  612.696514
# 2    ...       62.0               8.13         64.0        0.1  631.744976
# 3    ...       67.0               8.52         67.0        0.1  669.959000
# 4    ...       68.0               7.87         68.0        0.1   63.537231
#
#    Population   thinness  1-19 years   thinness 5-9 years  \
# 0  33736494.0                   17.2                 17.3
# 1    327582.0                   17.5                 17.5
# 2  31731688.0                   17.7                 17.7
# 3   3696958.0                   17.9                 18.0
# 4   2978599.0                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
#df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)]
Source_UAC=source.loc[(source['Country'] == "United States of America") | (source['Country'] == "Australia") |
                      (source['Country'] == "Canada") |  (source['Country'] == "Germany")]
Source_UAC
# Out:
#                        Country  Year  Status  Life expectancy   \
# 112                  Australia  2015       0              82.8
# 113                  Australia  2014       0              82.7
# 114                  Australia  2013       0              82.5
# 115                  Australia  2012       0              82.3
# 116                  Australia  2011       0              82.0
# 117                  Australia  2010       0              81.9
# 118                  Australia  2009       0              81.7
# 119                  Australia  2008       0              81.3
# 120                  Australia  2007       0              81.3
# 121                  Australia  2006       0              81.2
# 122                  Australia  2005       0              81.0
# 123                  Australia  2004       0              86.0
# 124                  Australia  2003       0              83.0
# 125                  Australia  2002       0              79.9
# 126                  Australia  2001       0              79.9
# 127                  Australia  2000       0              79.5
# 496                     Canada  2015       1              82.2
# 497                     Canada  2014       1              82.0
# 498                     Canada  2013       1              81.8
# 499                     Canada  2012       1              81.6
# 500                     Canada  2011       1              81.5
# 501                     Canada  2010       1              81.2
# 502                     Canada  2009       1              81.0
# 503                     Canada  2008       1              87.0
# 504                     Canada  2007       1              85.0
# 505                     Canada  2006       1              85.0
# 506                     Canada  2005       1              81.0
# 507                     Canada  2004       1              80.0
# 508                     Canada  2003       1              79.7
# 509                     Canada  2002       1              79.5
# ...                        ...   ...     ...               ...
# 996                    Germany  2013       0              86.0
# 997                    Germany  2012       0              86.0
# 998                    Germany  2011       0              85.0
# 999                    Germany  2010       0              81.0
# 1000                   Germany  2009       0              80.0
# 1001                   Germany  2008       0              79.9
# 1002                   Germany  2007       0              79.8
# 1003                   Germany  2006       0              79.6
# 1004                   Germany  2005       0              79.2
# 1005                   Germany  2004       0              79.1
# 1006                   Germany  2003       0              78.5
# 1007                   Germany  2002       0              78.4
# 1008                   Germany  2001       0              78.3
# 1009                   Germany  2000       0              78.0
# 2794  United States of America  2015       0              79.3
# 2795  United States of America  2014       0              79.1
# 2796  United States of America  2013       0              78.9
# 2797  United States of America  2012       0              78.8
# 2798  United States of America  2011       0              78.7
# 2799  United States of America  2010       0              78.7
# 2800  United States of America  2009       0              78.5
# 2801  United States of America  2008       0              78.2
# 2802  United States of America  2007       0              78.1
# 2803  United States of America  2006       0              77.8
# 2804  United States of America  2005       0              77.5
# 2805  United States of America  2004       0              77.5
# 2806  United States of America  2003       0              77.2
# 2807  United States of America  2002       0              77.0
# 2808  United States of America  2001       0              76.9
# 2809  United States of America  2000       0              76.8
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 112              59.0              1      NaN                0.000000
# 113               6.0              1     9.71            10769.363050
# 114              61.0              1     9.87            11734.853810
# 115              61.0              1    10.03            11714.998580
# 116              63.0              1    10.30            10986.265270
# 117              64.0              1    10.52             8875.786493
# 118              66.0              1    10.62             7172.275229
# 119              66.0              1    10.76             8547.292357
# 120              66.0              1    10.56              872.598609
# 121              66.0              1    10.31             6187.062017
# 122              67.0              1    10.30              579.133164
# 123              69.0              1     9.84              588.568371
# 124              71.0              1     9.97             3829.550928
# 125              73.0              1     9.84               46.387182
# 126              75.0              1     9.53             3064.301144
# 127              78.0              1    10.17              347.187360
# 496              64.0              2      NaN                0.000000
# 497              65.0              2     8.10              102.190217
# 498              67.0              2     8.20             9733.228019
# 499              68.0              2     8.30             9748.636237
# 500              68.0              2     8.20              971.928038
# 501               7.0              2     8.40             8649.674911
# 502              72.0              2     8.40              864.949930
# 503              74.0              2     8.30             8433.936814
# 504              74.0              2     8.30             7946.743581
# 505              75.0              2     8.20              771.181769
# 506              76.0              2     8.00             6333.177967
# 507              77.0              2     7.80             5513.329924
# 508              78.0              2     7.70             4687.845565
# 509              79.0              2     7.70             3895.856308
# ...               ...            ...      ...                     ...
# 996              71.0              2    10.94              895.877950
# 997              71.0              2    11.18              839.913320
# 998              74.0              2    11.20              869.790735
# 999              76.0              2    11.20             7584.078579
# 1000             79.0              2    11.22             7641.270645
# 1001              8.0              2    11.36             8285.264655
# 1002             82.0              3    11.50             7777.556353
# 1003             84.0              3    11.76             6407.535954
# 1004             85.0              3    11.67             6012.925840
# 1005             86.0              3    11.83             5842.374765
# 1006              9.0              3    11.92              582.615703
# 1007             91.0              3    12.25              437.105966
# 1008             92.0              3    12.46             4057.637383
# 1009             95.0              3    12.91             4238.540035
# 2794             13.0             23      NaN                0.000000
# 2795             14.0             23     8.82                0.000000
# 2796             16.0             23     8.82                0.000000
# 2797             16.0             24     8.82                0.000000
# 2798             16.0             25     8.67                0.000000
# 2799             15.0             25     8.55                0.000000
# 2800             18.0             26     8.71                0.000000
# 2801             18.0             27     8.74                0.000000
# 2802             11.0             27     8.74                0.000000
# 2803            113.0             28     8.63                0.000000
# 2804            112.0             28     8.52                0.000000
# 2805            111.0             28     8.48                0.000000
# 2806            114.0             28     8.40                0.000000
# 2807            115.0             28     8.33                0.000000
# 2808            115.0             28     8.25                0.000000
# 2809            114.0             28     8.21                0.000000
#
#       Hepatitis B  Measles     ...      Polio  Total expenditure  Diphtheria   \
# 112          93.0        74    ...       93.0                NaN         93.0
# 113          91.0       340    ...       92.0               9.42         92.0
# 114          91.0       158    ...       91.0               9.36         91.0
# 115          91.0       199    ...       92.0               9.36         92.0
# 116          92.0       190    ...       92.0               9.20         92.0
# 117          92.0        70    ...       92.0               9.20         92.0
# 118          94.0       104    ...       92.0               9.50         92.0
# 119          94.0        65    ...       92.0               8.78         92.0
# 120          94.0        11    ...       92.0               8.53         92.0
# 121          95.0         0    ...       92.0               8.49         92.0
# 122          95.0        10    ...       92.0               8.45         92.0
# 123          95.0        70    ...       92.0               8.57         92.0
# 124          95.0        91    ...       92.0               8.32         93.0
# 125          95.0        32    ...       92.0               8.39         92.0
# 126          94.0       141    ...       91.0               8.18         92.0
# 127           NaN       108    ...        9.0               8.80          9.0
# 496          55.0       195    ...       91.0                NaN         91.0
# 497          55.0       418    ...       91.0               1.45         91.0
# 498          55.0        83    ...       91.0               1.67         91.0
# 499           7.0        10    ...       99.0               1.78         95.0
# 500           7.0       803    ...       87.0               1.82         87.0
# 501          56.0        99    ...       88.0              11.20         89.0
# 502          42.0        14    ...       89.0              11.17         91.0
# 503          28.0        62    ...       89.0               1.30         92.0
# 504          14.0       101    ...        9.0               9.83         94.0
# 505          14.0        13    ...       95.0               9.75         95.0
# 506          14.0         6    ...       93.0               9.57         93.0
# 507          14.0         7    ...       91.0               9.56         91.0
# 508          14.0        15    ...       88.0               9.54         91.0
# 509           NaN         6    ...       88.0               9.37         88.0
# ...           ...       ...    ...        ...                ...          ...
# 996          88.0      1771    ...       94.0              11.16         95.0
# 997          88.0       166    ...       94.0               1.99         95.0
# 998          88.0      1607    ...       94.0               1.93         95.0
# 999          88.0       780    ...       94.0              11.25         95.0
# 1000         88.0       574    ...       95.0              11.40         96.0
# 1001         87.0       917    ...       95.0               1.39         96.0
# 1002         86.0       567    ...       95.0               1.18         96.0
# 1003         87.0      2307    ...       94.0               1.34         96.0
# 1004          9.0       778    ...       95.0               1.52         96.0
# 1005         88.0       121    ...       96.0               1.37         96.0
# 1006          9.0       779    ...       96.0               1.62         97.0
# 1007         87.0      4657    ...       97.0               1.40         93.0
# 1008         86.0      6024    ...       96.0               1.15         93.0
# 1009         84.0         0    ...       94.0               1.10          9.0
# 2794         92.0       188    ...       93.0                NaN         95.0
# 2795         92.0       667    ...       93.0              17.14         95.0
# 2796         91.0       187    ...       93.0              16.90         94.0
# 2797          9.0        55    ...       93.0              17.20         94.0
# 2798         91.0       220    ...       94.0              17.60         96.0
# 2799         92.0        63    ...       93.0              17.20         95.0
# 2800         92.0        71    ...       93.0              17.00         95.0
# 2801         94.0       140    ...       94.0              16.20         96.0
# 2802         93.0        43    ...       93.0              15.57         96.0
# 2803         93.0        55    ...       93.0              15.27         96.0
# 2804         93.0        66    ...       92.0              15.15         96.0
# 2805         92.0        37    ...       92.0              15.14         96.0
# 2806         92.0        56    ...       91.0              15.60         96.0
# 2807         88.0        41    ...        9.0              14.55         94.0
# 2808         89.0       116    ...       89.0              13.73         94.0
# 2809          9.0        85    ...        9.0              13.70         94.0
#
#        HIV/AIDS          GDP  Population   thinness  1-19 years  \
# 112         0.1  56554.38760  23789338.0                    0.6
# 113         0.1  62214.69120   2346694.0                    0.6
# 114         0.1  67792.33860  23117353.0                    0.6
# 115         0.1  67677.63477  22728254.0                    0.6
# 116         0.1  62245.12900    223424.0                    0.6
# 117         0.1  51874.84800    223175.0                    0.7
# 118         0.1  42742.99898    216917.0                    0.7
# 119         0.1  49664.68540    212492.0                    0.7
# 120         0.1   4991.98289     28276.0                    0.7
# 121         0.1  36118.28381     26979.0                    0.7
# 122         0.1   3416.71483     23948.0                    0.7
# 123         0.1   3472.37977     21274.0                    0.7
# 124         0.1  23465.38559    198954.0                    0.7
# 125         0.1    281.81763    196514.0                    0.7
# 126         0.1  19517.84168     19413.0                    0.7
# 127         0.1   2169.92100     19153.0                    0.7
# 496         0.1  43315.74400   3584861.0                    0.6
# 497         0.1    544.43376  35544564.0                    0.5
# 498         0.1  52413.72116  35155451.0                    0.5
# 499         0.1  52496.69487   3475545.0                    0.5
# 500         0.1   5282.21760   3434278.0                    0.5
# 501         0.1  47447.47620    345274.0                    0.5
# 502         0.1   4773.45436  33628571.0                    0.5
# 503         0.1  46596.33599  33245773.0                    0.5
# 504         0.1  44544.52680  32887928.0                    0.5
# 505         0.1   4386.69948    325755.0                    0.5
# 506         0.1  36189.58838     32312.0                    0.5
# 507         0.1  31979.87195     31995.0                    0.5
# 508         0.1  28172.14883     31676.0                    0.5
# 509         0.1  24167.84310     31362.0                    0.5
# ...         ...          ...         ...                    ...
# 996         0.1   4653.91143    864565.0                    1.1
# 997         0.1   4465.24891   8425823.0                    1.1
# 998         0.1   4681.32796   8274983.0                    1.1
# 999         0.1  41785.55691   8177693.0                    1.1
# 1000        0.1  41732.77250    819237.0                    1.1
# 1001        0.1  45699.19832    821197.0                    1.1
# 1002        0.1  41814.81910  82266372.0                    1.1
# 1003        0.1  36447.87232  82376451.0                    1.1
# 1004        0.1  34696.62920  82469422.0                    1.1
# 1005        0.1  34165.93430   8251626.0                    1.1
# 1006        0.1   3359.95215  82534176.0                    1.1
# 1007        0.1   2525.16445  82488495.0                    1.2
# 1008        0.1  23687.31689  82349925.0                    1.2
# 1009        0.1  23718.74670   8221158.0                    1.2
# 2794        0.1          NaN         NaN                    0.8
# 2795        0.1          NaN         NaN                    0.8
# 2796        0.1          NaN         NaN                    0.7
# 2797        0.1          NaN         NaN                    0.7
# 2798        0.1          NaN         NaN                    0.7
# 2799        0.1          NaN         NaN                    0.7
# 2800        0.1          NaN         NaN                    0.7
# 2801        0.1          NaN         NaN                    0.7
# 2802        0.1          NaN         NaN                    0.7
# 2803        0.1          NaN         NaN                    0.7
# 2804        0.1          NaN         NaN                    0.7
# 2805        0.1          NaN         NaN                    0.7
# 2806        0.1          NaN         NaN                    0.7
# 2807        0.1          NaN         NaN                    0.8
# 2808        0.1          NaN         NaN                    0.8
# 2809        0.1          NaN         NaN                    0.8
#
#        thinness 5-9 years  Income composition of resources  Schooling
# 112                   0.6                            0.937       20.4
# 113                   0.6                            0.936       20.4
# 114                   0.6                            0.933       20.3
# 115                   0.6                            0.930       20.1
# 116                   0.6                            0.927       19.8
# 117                   0.6                            0.927       19.5
# 118                   0.6                            0.925       19.1
# 119                   0.6                            0.921       19.1
# 120                   0.6                            0.918       19.0
# 121                   0.6                            0.915       20.3
# 122                   0.6                            0.910       20.3
# 123                   0.6                            0.908       20.7
# 124                   0.7                            0.905       20.6
# 125                   0.7                            0.902       20.1
# 126                   0.7                            0.899       20.5
# 127                   0.7                            0.897       20.4
# 496                   0.5                            0.919       16.3
# 497                   0.5                            0.912       15.9
# 498                   0.5                            0.909       15.9
# 499                   0.5                            0.907       15.9
# 500                   0.5                            0.903       15.9
# 501                   0.4                            0.898       15.9
# 502                   0.4                            0.898       15.9
# 503                   0.4                            0.897       15.8
# 504                   0.4                            0.894       15.8
# 505                   0.4                            0.891       15.8
# 506                   0.4                            0.886       15.8
# 507                   0.4                            0.881       15.8
# 508                   0.4                            0.877       15.8
# 509                   0.4                            0.872       15.8
# ...                   ...                              ...        ...
# 996                   1.1                            0.919       16.9
# 997                   1.1                            0.916       16.9
# 998                   1.1                            0.912       16.8
# 999                   1.1                            0.907       16.7
# 1000                  1.1                            0.906       16.7
# 1001                  1.1                            0.903       16.6
# 1002                  1.1                            0.898       16.6
# 1003                  1.1                            0.892       16.5
# 1004                  1.1                            0.884       16.4
# 1005                  1.1                            0.877       16.4
# 1006                  1.1                            0.872       16.3
# 1007                  1.1                            0.867       16.3
# 1008                  1.1                            0.860       16.2
# 1009                  1.2                            0.855       16.2
# 2794                  0.6                              NaN        NaN
# 2795                  0.6                              NaN        NaN
# 2796                  0.6                              NaN        NaN
# 2797                  0.6                              NaN        NaN
# 2798                  0.6                              NaN        NaN
# 2799                  0.6                              NaN        NaN
# 2800                  0.6                              NaN        NaN
# 2801                  0.6                              NaN        NaN
# 2802                  0.6                              NaN        NaN
# 2803                  0.6                              NaN        NaN
# 2804                  0.6                              NaN        NaN
# 2805                  0.6                              NaN        NaN
# 2806                  0.6                              NaN        NaN
# 2807                  0.6                              NaN        NaN
# 2808                  0.6                              NaN        NaN
# 2809                  0.7                              NaN        NaN
#
# [64 rows x 22 columns]

# %%
source = Source_UAC

alt.Chart(Source_UAC).transform_filter(
    alt.datum.symbol != 'GOOG'
).mark_area().encode(
    x='Year:O',
    y='Hepatitis B:Q',
    color='Country:N',
    row=alt.Row('Country:N')
).properties(height=50, width=400).interactive()
# Out:
# <div class="vega-embed" id="5be25719-9f1c-429b-bb67-088074144367"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
alt.Chart(Source_UAC).mark_circle().encode(
    alt.X(alt.repeat("column"), type='ordinal'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='Country:N'
).properties(
    width=150,
    height=150
).repeat(
    row=['percentage expenditure', 'Population'],
    column=['Year']
).interactive()
# Out:
# <div class="vega-embed" id="948873c0-b6d5-43f7-b07f-c0ad2a12cc1c"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
alt.Chart(Source_UAC).mark_circle().encode(
    x='Year:O',
    y='GDP:Q',
    color='Country'
).interactive()
# Out:
# <div class="vega-embed" id="8345bdea-c603-4d35-928e-1a5fbf26241e"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
alt.Chart(Source_UAC).mark_circle().encode(
    x='Year:O',
    y='Adult Mortality:Q',
    size='average(Adult Mortality):Q',
    color='Country:N'
).interactive()
# Out:
# <div class="vega-embed" id="cd03969d-105b-4637-8d91-3455bf2ce7ce"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
source_2015=source.loc[source.Year==2015]
source_2014=source.loc[source.Year==2014]
source_2013=source.loc[source.Year==2013]
source_2015
# Out:
#                        Country  Year  Status  Life expectancy   \
# 112                  Australia  2015       0              82.8
# 496                     Canada  2015       1              82.2
# 994                    Germany  2015       0              81.0
# 2794  United States of America  2015       0              79.3
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 112              59.0              1      NaN                     0.0
# 496              64.0              2      NaN                     0.0
# 994              68.0              2      NaN                     0.0
# 2794             13.0             23      NaN                     0.0
#
#       Hepatitis B  Measles     ...      Polio  Total expenditure  Diphtheria   \
# 112          93.0        74    ...       93.0                NaN         93.0
# 496          55.0       195    ...       91.0                NaN         91.0
# 994          88.0      2464    ...       94.0                NaN         95.0
# 2794         92.0       188    ...       93.0                NaN         95.0
#
#        HIV/AIDS          GDP  Population   thinness  1-19 years  \
# 112         0.1  56554.38760  23789338.0                    0.6
# 496         0.1  43315.74400   3584861.0                    0.6
# 994         0.1  41176.88158  81686611.0                    1.1
# 2794        0.1          NaN         NaN                    0.8
#
#        thinness 5-9 years  Income composition of resources  Schooling
# 112                   0.6                            0.937       20.4
# 496                   0.5                            0.919       16.3
# 994                   1.1                            0.924       17.1
# 2794                  0.6                              NaN        NaN
#
# [4 rows x 22 columns]

# %%
base = alt.Chart(source_2015)

bar = base.mark_bar().encode(
    x=alt.X('Population:Q', bin=True, axis=None),
    y='count()',
     color='Country:N'
)

rule = base.mark_rule(color='red').encode(
    x='mean(Population):Q',
    size=alt.value(5)
).interactive()

bar + rule
# Out:
# <div class="vega-embed" id="c9a1ccda-1b47-40b5-b80d-947cce597418"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
